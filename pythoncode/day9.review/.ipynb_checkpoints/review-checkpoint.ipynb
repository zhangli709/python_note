# %% [markdown]
# # 总结和复习
#
# ## 函数
# ```Python  # 相对独立的，可能在将来使用的，写成函数，方便使用。
# def f(a=0, b=0):
#     return a + b
# def f(*rags): #可变参数
#     total = 0
#     for val in args:
#         total += val
#     return total
#
# f()
#
#
# mylist = [1, 3, 5, 10, 20]
# print(f(*mylist)) # 把一个列表中的元素传入函数中，记得加*
# ```
#
#
#
# 作用域 - LEGB(local enclose global built-in)
#
#
# ```Python
# a = 100 # 全局变量，尽量减少全局变量的使用。迪米特法则：不要的陌生人讲话！
#
#
# def f():
#     global a
#     a = 200
#     b = 'hello'
#
#
#     def g():
#         nonlocal b
#         b = 'good'
#
# ```
# ```调用函数时：执行现场，保存现场
#     函数调用自身：叫递归函数！满足条件：1.函数表达式。2.返回条件。
#
# ```
#
#
#
# ## 模块
# ```from 模块名 import 指定的函数 （as 别名）
# 模块 ：单一职责原则！
# ```
#
# ## 字符串
# ```Python
#
# ```
#
# ## 列表
# ```Python  list
# 创建方法：1.[直接放值] 2.list() 3.生成式语法：[x for x in range(1, 10)]
# 加值： mylist = mylist + [11]    append
# 减值： remove del clear
# 切片： [:]
# 判断： in
# 排序： sort (sorted)
#
# ```
#
# ## 内存管理
# 栈 变量--地址--对象的引用
# 堆 真正的对象
# id() 查看地址
# is   判断
# sys.getsizeof  看大小
# sys.getrefcount 看有几个引用对象
# 静态区
